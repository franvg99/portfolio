# %% [markdown]
# # 📰 Clasificador de Noticias Falsas y Verdaderas con NLP y Deep Learning
#
# Este proyecto utiliza procesamiento de lenguaje natural (NLP) y un modelo de deep learning para **clasificar noticias como reales o falsas** a partir de sus títulos.
#
# ---
#
# ## 📌 Objetivo
#
# Desarrollar un sistema capaz de predecir si una noticia es verdadera o falsa, basado únicamente en el **título de la noticia**, aplicando técnicas de procesamiento de lenguaje natural y aprendizaje profundo.
#
# ---
#
# ## 🧠 Tecnologías Utilizadas
#
# - Python
# - Pandas / NumPy
# - Matplotlib / Seaborn
# - NLTK
# - WordCloud
# - TensorFlow / Keras
# - Scikit-learn
# - Google Colab
#
# ---
#
# ## 📂 Dataset
#
# Se utilizaron dos datasets disponibles públicamente:
#
# - `True.csv`: noticias verdaderas
# - `Fake.csv`: noticias falsas
#
# Cada uno contiene títulos, textos y otras variables, pero para este proyecto se trabajó solamente con el **título de la noticia**.
#
# ---
#
# ## 📁 Estructura del proyecto
#
# - `Fake and Real News Dataset`: conjunto de datos utilizado.
# - `Análisis Exploratorio`: análisis visual y estadístico de palabras más frecuentes.
# - `Preprocesamiento de datos`: limpieza de texto y tokenización.
# - `Entrenamiento del modelo`: red neuronal con embedding + capas densas.
# - `Evaluación`: métricas de desempeño y ejemplos de predicción reales.
# - `Prevención de sobreajuste`: uso de Dropout y EarlyStopping.
# - `Predicción`: prueba con títulos nuevos en inglés.
#
# ---
#
# ## 🔍 Fase 1: Procesamiento NLP
#
# - Tokenización y limpieza de texto
# - Frecuencia de palabras
# - Comparación de palabras más comunes
# - Visualización con nubes de palabras
#
# ---
#
# ## ☁️ Nubes de Palabras
#
# ### 📊 Word Cloud - Noticias Verdaderas
# !![nube_palabras_true.png](data:image/png;base64,...)
#
# ### 🧪 Word Cloud - Noticias Falsas
# ![nube_palabras_fake.png](data:image/png;base64,...)
# ---
#
# ## 🤖 Fase 2: Deep Learning
#
# Se utilizó una red neuronal simple (MLP) con Keras:
#
# ```python
# model = Sequential([
#     Embedding(input_dim=5000, output_dim=16, input_length=30),
#     GlobalAveragePooling1D(),
#     Dense(24, activation='relu'),
#     Dropout(0.5),
#     Dense(1, activation='sigmoid')
# ])
# ```
# ---
#
# ## 📊 Resultados
#
# - **Precisión de validación**: > 97%
# - El modelo detecta de forma confiable noticias falsas con base en el título.
# - Probado con ejemplos reales e inventados, respondiendo con lógica y coherencia.
#
# ---
#
# ## 🚀 Cómo ejecutarlo
#
# 1. Clona el repositorio:
#    ```bash
#    git clone https://github.com/tuusuario/fake-news-detector.git
#    cd fake-news-detector
